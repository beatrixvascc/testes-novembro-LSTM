# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix,
    ConfusionMatrixDisplay, accuracy_score, average_precision_score
)
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from imblearn.over_sampling import BorderlineSMOTE

# --- Carregar dados ---
dados = np.load("/content/sem_bal_mimic_X_y_1h.npz")

X = dados['X']
y = dados['y']
mask = dados['mask']

# %%
# Primeiro: treino (70%) e restante (30%)
X_train, X_temp, y_train, y_temp, mask_train, mask_temp = train_test_split(
    X, y, mask, test_size=0.30, random_state=42, stratify=y
)

# Depois: dividir os 30% restantes em 50/50 -> 15% validação + 15% teste
X_val, X_test, y_val, y_test, mask_val, mask_test = train_test_split(
    X_temp, y_temp, mask_temp, test_size=0.50, random_state=42, stratify=y_temp
)

print(f"Treino: {len(X_train)} amostras ({len(X_train)/len(X)*100:.1f}%)")
print(f"Validação: {len(X_val)} amostras ({len(X_val)/len(X)*100:.1f}%)")
print(f"Teste: {len(X_test)} amostras ({len(X_test)/len(X)*100:.1f}%)")
# Out:
# Treino: 35632 amostras (70.0%)
# Validação: 7636 amostras (15.0%)
# Teste: 7636 amostras (15.0%)

# %%
def normalize_split_data(X_train, X_val, X_test):
    n_samples, n_janelas, n_features = X_train.shape
    X_train_norm = np.zeros_like(X_train, dtype=np.float32)
    X_val_norm = np.zeros_like(X_val, dtype=np.float32)
    X_test_norm = np.zeros_like(X_test, dtype=np.float32)
    scalers = []

    for i in range(n_features):
        scaler = StandardScaler()
        feat_train = X_train[:, :, i].reshape(-1, 1)
        scaler.fit(feat_train)

        X_train_norm[:, :, i] = scaler.transform(feat_train).reshape(n_samples, n_janelas)
        X_val_norm[:, :, i] = scaler.transform(X_val[:, :, i].reshape(-1, 1)).reshape(X_val.shape[0], n_janelas)
        X_test_norm[:, :, i] = scaler.transform(X_test[:, :, i].reshape(-1, 1)).reshape(X_test.shape[0], n_janelas)

        scalers.append(scaler)

    return X_train_norm, X_val_norm, X_test_norm, scalers

X_train_norm, X_val_norm, X_test_norm, scalers = normalize_split_data(X_train, X_val, X_test)
joblib.dump(scalers, "scalers_standard_lstm.pkl")
# Out:
# ['scalers_standard_lstm.pkl']

# %%
n_samples, n_janelas, n_features = X_train_norm.shape
X_train_2d = X_train_norm.reshape(n_samples, -1)

smote = BorderlineSMOTE(sampling_strategy=0.50, random_state=42)
X_res, y_res = smote.fit_resample(X_train_2d, y_train)

# Voltar para 3D
X_train = X_res.reshape(X_res.shape[0], n_janelas, n_features)
y_train = y_res

# Atualizar splits
X_val, X_test = X_val_norm, X_test_norm
input_shape = X_train.shape[1:]

# %%
class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, units=32, **kwargs):
        super().__init__(**kwargs)
        self.units = units

    def build(self, input_shape):
        self.W = tf.keras.layers.Dense(self.units, use_bias=True)
        self.V = tf.keras.layers.Dense(1, use_bias=False)
        super().build(input_shape)

    def call(self, inputs, mask=None):
        score = self.V(tf.nn.tanh(self.W(inputs)))  # (batch, time, 1)
        score = tf.squeeze(score, axis=-1)          # (batch, time)

        if mask is not None:
            mask = tf.cast(mask, dtype=score.dtype)
            score = score * mask + (1.0 - mask) * -1e9  # ignora padding

        alphas = tf.nn.softmax(score, axis=1)
        alphas_exp = tf.expand_dims(alphas, axis=-1)
        context = tf.reduce_sum(inputs * alphas_exp, axis=1)
        return context

    def get_config(self):
        config = super().get_config()
        config.update({"units": self.units})
        return config

# %%
inputs = tf.keras.Input(shape=input_shape)
x = layers.Masking(mask_value=0.0)(inputs)
x = layers.LSTM(64, return_sequences=True)(x)
context = AttentionLayer(units=32)(x)
x = layers.Dropout(0.3)(context)
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=[
        tf.keras.metrics.BinaryAccuracy(name='accuracy'),
        tf.keras.metrics.AUC(name='auc'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
)

model.summary()

# ===============================================================
# Treinamento (usando validação separada)
# ===============================================================
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=70,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:965: UserWarning: Layer 'attention_layer_3' (of type AttentionLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 10, 8)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_3         │ (None, 10, 8)     │          0 │ input_layer_3[0]… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking_3 (Masking) │ (None, 10, 8)     │          0 │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_3 (Any)         │ (None, 10)        │          0 │ not_equal_3[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ (None, 10, 64)    │     18,688 │ masking_3[0][0],  │
# │                     │                   │            │ any_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_layer_3   │ (None, 64)        │      2,112 │ lstm_3[0][0],     │
# │ (AttentionLayer)    │                   │            │ any_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 64)        │          0 │ attention_layer_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 32)        │      2,080 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 1)         │         33 │ dense_14[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,913 (89.50 KB)
#  Trainable params: 22,913 (89.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.7208 - auc: 0.7619 - loss: 0.5411 - precision: 0.5923 - recall: 0.5681 - val_accuracy: 0.7914 - val_auc: 0.7754 - val_loss: 0.4196 - val_precision: 0.3302 - val_recall: 0.5431
# Epoch 2/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - accuracy: 0.7580 - auc: 0.8072 - loss: 0.4979 - precision: 0.6525 - recall: 0.5928 - val_accuracy: 0.8097 - val_auc: 0.7784 - val_loss: 0.4171 - val_precision: 0.3547 - val_recall: 0.5147
# Epoch 3/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.7643 - auc: 0.8180 - loss: 0.4861 - precision: 0.6583 - recall: 0.6113 - val_accuracy: 0.7931 - val_auc: 0.7764 - val_loss: 0.4231 - val_precision: 0.3349 - val_recall: 0.5538
# Epoch 4/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.7668 - auc: 0.8213 - loss: 0.4811 - precision: 0.6622 - recall: 0.6068 - val_accuracy: 0.7914 - val_auc: 0.7738 - val_loss: 0.4200 - val_precision: 0.3320 - val_recall: 0.5519
# Epoch 5/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.7676 - auc: 0.8297 - loss: 0.4737 - precision: 0.6676 - recall: 0.6164 - val_accuracy: 0.8058 - val_auc: 0.7734 - val_loss: 0.4104 - val_precision: 0.3492 - val_recall: 0.5225
# Epoch 6/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.7745 - auc: 0.8359 - loss: 0.4640 - precision: 0.6746 - recall: 0.6169 - val_accuracy: 0.7939 - val_auc: 0.7698 - val_loss: 0.4370 - val_precision: 0.3351 - val_recall: 0.5489
# Epoch 7/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.7805 - auc: 0.8403 - loss: 0.4599 - precision: 0.6902 - recall: 0.6218 - val_accuracy: 0.8096 - val_auc: 0.7723 - val_loss: 0.4022 - val_precision: 0.3490 - val_recall: 0.4883
# Epoch 8/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.7796 - auc: 0.8429 - loss: 0.4574 - precision: 0.6876 - recall: 0.6240 - val_accuracy: 0.8098 - val_auc: 0.7680 - val_loss: 0.3984 - val_precision: 0.3464 - val_recall: 0.4746
# Epoch 9/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.7837 - auc: 0.8484 - loss: 0.4503 - precision: 0.6922 - recall: 0.6371 - val_accuracy: 0.7943 - val_auc: 0.7661 - val_loss: 0.4240 - val_precision: 0.3292 - val_recall: 0.5176
# Epoch 10/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - accuracy: 0.7828 - auc: 0.8475 - loss: 0.4517 - precision: 0.6922 - recall: 0.6354 - val_accuracy: 0.8100 - val_auc: 0.7667 - val_loss: 0.4076 - val_precision: 0.3497 - val_recall: 0.4883
# Epoch 11/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.7868 - auc: 0.8522 - loss: 0.4442 - precision: 0.6958 - recall: 0.6351 - val_accuracy: 0.7979 - val_auc: 0.7690 - val_loss: 0.4220 - val_precision: 0.3363 - val_recall: 0.5235
# Epoch 12/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.7915 - auc: 0.8585 - loss: 0.4343 - precision: 0.6988 - recall: 0.6438 - val_accuracy: 0.7885 - val_auc: 0.7654 - val_loss: 0.4362 - val_precision: 0.3253 - val_recall: 0.5401
# Epoch 13/70
# 1447/1447 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.7908 - auc: 0.8586 - loss: 0.4362 - precision: 0.7000 - recall: 0.6504 - val_accuracy: 0.8118 - val_auc: 0.7594 - val_loss: 0.4060 - val_precision: 0.3443 - val_recall: 0.4491

# %%
# ===============================================================
# Avaliação final no conjunto de teste (15%)
# ===============================================================
y_pred_prob = model.predict(X_test).flatten()
y_pred = (y_pred_prob >= 0.5).astype(int)

print("\n--- Resultados no conjunto de TESTE ---")
print(f"Acurácia: {accuracy_score(y_test, y_pred):.4f}")
print(f"AUC: {roc_auc_score(y_test, y_pred_prob):.4f}")
print(f"Precisão: {precision_score(y_test, y_pred):.4f}")
print(f"Revocação: {recall_score(y_test, y_pred):.4f}")
print(f"F1-score: {f1_score(y_test, y_pred):.4f}")
print(f"AUPRC: {average_precision_score(y_test, y_pred_prob):.4f}")

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Sem Sepse", "Com Sepse"])
disp.plot(cmap='Blues')
plt.title("Matriz de Confusão - LSTM com Atenção (Teste)")
plt.show()
# Out:
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# --- Resultados no conjunto de TESTE ---
# Acurácia: 0.8050
# AUC: 0.7649
# Precisão: 0.3326
# Revocação: 0.4554
# F1-score: 0.3845
# AUPRC: 0.3143
